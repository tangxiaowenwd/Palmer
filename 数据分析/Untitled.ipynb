# %%
import tushare as ts
import datetime
import pandas as pd
pro = ts.pro_api("d9f49767544519208fbf91e00a109558fe92e84bdcb70c9173144c24")


def get_sample_stock_daily(ts_code):
    df = pro.query('daily', ts_code='000001.SZ')
    return df

# %%
df = pro.query('daily_basic',trade_date='20201117',fields='ts_code,trade_date,turnover_rate,volume_ratio,pe,pb')
df
# Out:
#         ts_code trade_date  turnover_rate  volume_ratio        pe       pb
# 0     300142.SZ   20201117         3.2800          1.08  486.6008  11.9601
# 1     603232.SH   20201117         0.7471          0.79   74.6226   4.2101
# 2     300025.SZ   20201117         3.2424          0.48       NaN   5.3500
# 3     300605.SZ   20201117         5.2149          1.06   41.6939   4.3112
# 4     605009.SH   20201117         9.9476          1.38   60.5132   7.1166
# 5     600674.SH   20201117         0.1907          1.30   15.4896   1.6497
# 6     600723.SH   20201117         1.9945          1.32   19.5062   1.9053
# 7     300721.SZ   20201117        15.3305          1.79  421.9420   3.2942
# 8     300169.SZ   20201117         3.0157          0.94       NaN   2.4605
# 9     603721.SH   20201117         1.8513          1.34   98.5626   3.5742
# 10    600166.SH   20201117         7.6959          2.18  116.3729   1.4390
# ...

# %%
for i in df.iterrows():
    print(i)
# Out:
# (0, ts_code         000001.SZ
# trade_date       20201110
# open                   18
# high                 18.5
# low                 17.93
# close               18.11
# pre_close           17.84
# change               0.27
# pct_chg            1.5135
# vol           1.02106e+06
# amount        1.85414e+06
# Name: 0, dtype: object)
# (1, ts_code         000001.SZ
# trade_date       20201109
# open                17.67
# high                   18
# low                 17.54
# close               17.84
# pre_close           17.64
# change                0.2
# pct_chg            1.1338
# vol                951424
# amount        1.68881e+06
# Name: 1, dtype: object)
# (2, ts_code         000001.SZ
# trade_date       20201106
# open                17.71
# high                17.75
# low                 17.22
# close               17.64
# pre_close            17.7
# change              -0.06
# pct_chg            -0.339
# vol                848782
# amount        1.48649e+06
# ...

# %%
df
# Out:
#         ts_code trade_date   open   high    low  close  pre_close  change  \
# 0     000001.SZ   20201110  18.00  18.50  17.93  18.11      17.84    0.27
# 1     000001.SZ   20201109  17.67  18.00  17.54  17.84      17.64    0.20
# 2     000001.SZ   20201106  17.71  17.75  17.22  17.64      17.70   -0.06
# 3     000001.SZ   20201105  18.37  18.50  17.54  17.70      18.32   -0.62
# 4     000001.SZ   20201104  18.35  18.48  17.96  18.32      17.96    0.36
# 5     000001.SZ   20201103  17.71  18.34  17.70  17.96      17.63    0.33
# 6     000001.SZ   20201102  17.65  18.05  17.33  17.63      17.75   -0.12
# 7     000001.SZ   20201030  17.74  18.36  17.60  17.75      17.77   -0.02
# 8     000001.SZ   20201029  17.54  17.93  17.35  17.77      17.63    0.14
# 9     000001.SZ   20201028  17.76  17.90  17.29  17.63      17.76   -0.13
# 10    000001.SZ   20201027  18.00  18.00  17.50  17.76      17.70    0.06
# 11    000001.SZ   20201026  18.20  18.29  17.45  17.70      18.13   -0.43
# ...
