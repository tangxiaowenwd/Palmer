# %%
import tushare as ts
import cv2
import scipy.misc as sm
import matplotlib.pyplot as mp

# %%
img= cv2.imread("./data/flow.jpg",True)
b,g,r = cv2.split(img) 
img_rgb = cv2.merge([r,g,b]) 
mp.imshow(img_rgb)

# %%
mp.imshow(cropped,cmap='gray')

# %%
cropped = img_rgb[0:375, 95:470]
cropped = cv2.cvtColor(cropped,cv2.COLOR_RGB2GRAY)
cropped = np.mat(cropped)
mp.imshow(cropped)
cropped.shape
# Out:
# (375, 375)

# %%
eigvals,eigvecs = np.linalg.eig(cropped)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-85-3db25fb42b36> in <module>
# ----> 1 eigvals,eigvecs = np.linalg.eig(cropped)
#
# <__array_function__ internals> in eig(*args, **kwargs)
#
# d:\python\lib\site-packages\numpy\linalg\linalg.py in eig(a)
#    1309         _raise_linalgerror_eigenvalues_nonconvergence)
#    1310     signature = 'D->DD' if isComplexType(t) else 'd->DD'
# -> 1311     w, vt = _umath_linalg.eig(a, signature=signature, extobj=extobj)
#    1312
#    1313     if not isComplexType(t) and all(w.imag == 0.0):
#
# d:\python\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_eigenvalues_nonconvergence(err, flag)
#     101
#     102 def _raise_linalgerror_eigenvalues_nonconvergence(err, flag):
# --> 103     raise LinAlgError("Eigenvalues did not converge")
#     104
#     105 def _raise_linalgerror_svd_nonconvergence(err, flag):
#
# ...

# %%
a = np.diag(eigvals)
a.shape
# Out:
# (2, 2)

# %%
dst = eigvecs * np.diag(eigvals) * eigvecs.I
dst
# Out:
# matrix([[ 3.00000000e+00, -2.00000000e+00],
#         [ 1.00000000e+00, -4.05861454e-17]])

# %%
mp.imshow(dst.real,cmap='gray')

# %%
A = np.mat('3 -2;1 0')
A
# Out:
# matrix([[ 3, -2],
#         [ 1,  0]])

# %%
eigvals,eigvecs = np.linalg.eig(A)
eigvecs[1:0] = 0
eigvecs
# Out:
# matrix([[0.89442719, 0.70710678],
#         [0.4472136 , 0.70710678]])

# %%
dst = eigvecs * np.diag(eigvals) * eigvecs.I
dst
# Out:
# matrix([[ 3.00000000e+00, -2.00000000e+00],
#         [ 1.00000000e+00, -4.05861454e-17]])

# %%
mp.imshow(dst)

# %%
cropped = img_rgb[0:375, 95:470]
cropped = cv2.cvtColor(cropped,cv2.COLOR_RGB2GRAY)
mp.imshow(cropped)
cropped.shape
# Out:
# (375, 375)
